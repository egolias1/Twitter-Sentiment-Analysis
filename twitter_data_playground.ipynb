# %%
from minio import Minio
import json
import os

from dotenv import load_dotenv
load_dotenv()  # take environment variables from .env.
# Out:
# True

# %%
s3_access_key = os.environ.get("S3_ACCESS_KEY")
s3_secret_key = os.environ.get("S3_SECRET_KEY")
bucket = "twitter-data-123456"
s3_client = Minio("storage.googleapis.com", access_key=s3_access_key, secret_key=s3_secret_key)

# %%
response = s3_client.get_object(bucket, "test_tweets_3/1.json")
print(response.data.decode('utf-8'))
data = json.loads(response.data.decode('utf-8'))
# Out:
# [
#     {
#         "data": {
#             "id": "1488709655954034696",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@AndyTheGreat100 @driptotoken \ud83d\udd25\ud83d\udd25\ud83d\udd25"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709657208430594",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1623
#             },
#             "text": "RT @Holywargame: \ud83c\udf1fFirst HolyWar Airdrop \ud83c\udf1f\n\n\ud83d\udcb0 Airdrop : 50K $HOL for 2500 Winners\n\ud83d\udcc6 End date: 15 FEB 2022\n\n\u27a1\ufe0fLike + RT + Follow and tag 3 Fr\u2026"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709656357011459",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@J0hnnyinCRYPT0 #NFT to the moon"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709659259129858",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@rjmath2 @piggybankersNFT check this out!"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709658714210305",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1623
#             },
#             "text": "RT @Holywargame: \ud83c\udf1fFirst HolyWar Airdrop \ud83c\udf1f\n\n\ud83d\udcb0 Airdrop : 50K $HOL for 2500 Winners\n\ud83d\udcc6 End date: 15 FEB 2022\n\n\u27a1\ufe0fLike + RT + Follow and tag 3 Fr\u2026"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709660832059396",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 267
#             },
#             "text": "RT @JaysHere_: 1 Winner \ud83d\udc51= $500 in #ETH \ud83c\udf81\n\n-&gt; Retweet, Like &amp; Follow \n-&gt; Show me you got notifications on\n\n45 Minutes!"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709659523710981",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 777
#             },
#             "text": "RT @darkswrld: PIGGY BANKERS MINT IS TOMORROW: 02/02/22\n\nPRESALES: 11:30AM EST- 5:30PM CET \nPUBLIC : 12PM EST- 6 PM CET \n  \nJOIN their crew\u2026"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709659749986313",
#             "public_metrics": {
#                 "like_count": 1,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "#NFTdrop #NFTupcoming #NFTpresale #NFTGiveaways #NFT #NFTCommmunity #Metaverse #NFTCollection #nftcollectors #Ethereum #opensea #NFTs #NFTgiveaway #NFTLaunch #ethereumNFT #NFTGiveaway #utilityNFT #NFTutility #NFTWitelist #Whitelist #NFTgem #NFTnews #NFTart https://t.co/SwjehyhyOh"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709660286746630",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "Good airdrop\n@ha_hoang0104 \n@trangnguyen0206 \n@tranminhha \n#Airdrop #BSC #Bitcoin\u00a0\u00a0 #ETH #DarkLandSurvival #BIG #Airdropstario https://t.co/HjFC1TuRGd"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709665676730368",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 651
#             },
#             "text": "RT @LTCGifting: Who still needs some $ETH? \ud83e\udd29\n\n- Follow, Like &amp; RT\n- Drop your #ETH wallet and I\u2019ll send some! \ud83d\udc47 https://t.co/NX2QvpjdiT"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709664304816128",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 133
#             },
#             "text": "RT @DogeWofficial: NEW TOP-DOG ON THE BLOCK! \ud83d\udcaa\ud83d\ude0d\nPRESALE AND THEN LAUNCH ON #PancakeSwap \n\nLIFT OFF - 15:00 UTC \ud83d\ude80\ud83d\udd25\n\nJOIN HERE https://t.co/5\u2026"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709663424225280",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 3
#             },
#             "text": "RT @Dione954: @boris1777 @Whitecoatcrypt0 @ShibnobiStrong @Shib_nobi @Free_Patriot76 \ud83d\udd31#SHIBNOBI #SHINJA $SHINJA \ud83d\udd31\n#ShinjaIsTheNext1000X #Sh\u2026"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488

#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "I am very happy to be a part of this project, hopefully in the future it will be more developed and successful.\n\n@IKRaj47 \n@RajuIsl88763424 \n@Badhan13843209\n\n#TallyToken https://t.co/JziuiCqJyS"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709719007318016",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 4021
#             },
#             "text": "RT @karaholiday17: Partnered with @EtherealartNFT to \ngiveaway 10 WL spots &lt;3\n\n40k discord in 48 hours\nKnown artist 1.1 million followers\u2026"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709717039861760",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1
#             },
#             "text": "RT @foday_church: I've just created \"Uchiha, Foday\" collectible! https://t.co/1IMJlRSTHI #rarible #ethereum #nonfungible #digitalasset #nft\u2026"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709710467510276",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 0
#             },
#             "text": "@dogecolorart @tajmahaltur SHIBEV - ShibaElonVerse is the next token that will revolutionize the Metaverse.\n\n\ud83d\udd25 CoinGecko Listed\n\n\ud83d\udd25 AUDIT with CoinScope\n\n\ud83d\udd25 KYC with Nanuqe\n\n\ud83d\udd25 7% Cardano (ADA) Rewards\n\nOfficial Telegram: https://t.co/gsxljfnkz5\n\nTwitter: https://t.co/ulzWYdUz6X"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709713055268864",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 1805
#             },
#             "text": "RT @BoujeFinance: Vive La Bouje Shining the light of capitalism - Le capitalisme brille sur le monde\"\n\nWebsite: https://t.co/XUSC11cuzw\n\n#F\u2026"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     },
#     {
#         "data": {
#             "id": "1488709722127872002",
#             "public_metrics": {
#                 "like_count": 0,
#                 "quote_count": 0,
#                 "reply_count": 0,
#                 "retweet_count": 171
#             },
#             "text": "RT @Cryptopenelope: \ud83d\udea8PIGGY BANKERS ARE MINT NOW: 02/02/2022 \ud83d\udc16\ud83d\udc37 \n\nPRESALES: 11:30AM EST - 5:30PM CET\nPUBLIC: 12PM EST - 6PM CET\n\n\ud83d\udcccJOIN their\u2026"
#         },
#         "matching_rules": [
#             {
#                 "id": "1488709617274089477",
#                 "tag": ""
#             }
#         ]
#     }
# ]

# %%
print(data[0]["data"]["text"])
# Out:
# @AndyTheGreat100 @driptotoken 🔥🔥🔥

# %%
#Testing a basic implementation of CBOW

CONTEXT_SIZE = 2  # 2 words to the left, 2 to the right
raw_text = """We are about to study the idea of a computational process.
Computational processes are abstract beings that inhabit computers.
As they evolve, processes manipulate other abstract things called data.
The evolution of a process is directed by a pattern of rules
called a program. People create programs to direct processes. In effect,
we conjure the spirits of the computer with our spells.""".split()

# By deriving a set from `raw_text`, we deduplicate the array
vocab = set(raw_text)
vocab_size = len(vocab)

word_to_ix = {word: i for i, word in enumerate(vocab)}
data = []
for i in range(CONTEXT_SIZE, len(raw_text) - CONTEXT_SIZE):
    context = (
        [raw_text[i - j - 1] for j in range(CONTEXT_SIZE)]
        + [raw_text[i + j + 1] for j in range(CONTEXT_SIZE)]
    )
    target = raw_text[i]
    data.append((context, target))
print(data[:5])


class CBOW(nn.Module):

    def __init__(self):
        pass

    def forward(self, inputs):
        pass

# Create your model and train. Here are some functions to help you make
# the data ready for use by your module.


def make_context_vector(context, word_to_ix):
    idxs = [word_to_ix[w] for w in context]
    return torch.tensor(idxs, dtype=torch.long)


make_context_vector(data[0][0], word_to_ix)  # example
# Out:
# [(['are', 'We', 'to', 'study'], 'about'), (['about', 'are', 'study', 'the'], 'to'), (['to', 'about', 'the', 'idea'], 'study'), (['study', 'to', 'idea', 'of'], 'the'), (['the', 'study', 'of', 'a'], 'idea')]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [5], in <module>
#      23     data.append((context, target))
#      24 print(data[:5])
# ---> 27 class CBOW(nn.Module):
#      29     def __init__(self):
#      30         pass
#
# NameError: name 'nn' is not defined
